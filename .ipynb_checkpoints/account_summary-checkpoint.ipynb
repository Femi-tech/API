# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
import datetime
import json
import pandas as pd
from dotenv import load_dotenv

# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SBX_SECRET_KEY = os.getenv("PLAID_SBX_SECRET_KEY")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %%
type(PLAID_CLIENT_ID)
type(PLAID_PUBLIC_KEY)
type(PLAID_SBX_SECRET_KEY)
# Out:
# str

# %%
print(len(PLAID_CLIENT_ID))
print(len(PLAID_PUBLIC_KEY))
print(len(PLAID_SBX_SECRET_KEY))
# Out:
# 24
# 30
# 30

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
from plaid import Client

client = Client(
  client_id=PLAID_CLIENT_ID,
  secret=PLAID_SBX_SECRET_KEY,
  environment='sandbox',
  api_version='2019-05-29'
)

# %%
# Set the institution id
INSTITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])
# Print the public token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Retrieve the access token
access_token = exchange_response['access_token']
# Print the access token
print (access_token)
# Out:
# access-sandbox-17407098-62e2-47c2-b5c5-ad67095bb272

# %%
# Store the access token in a Python variable
access_token = exchange_response["access_token"]

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
client_account = client.Accounts.get(access_token)
# Print accounts
print(client_account)
# Out:
# {'accounts': [{'account_id': 'GqoNxvB5lmUengBxorZPhk3Axaewwgs15rxN3', 'balances': {'available': 100, 'current': 110, 'iso_currency_code': 'USD', 'limit': None, 'unofficial_currency_code': None}, 'mask': '0000', 'name': 'Plaid Checking', 'official_name': 'Plaid Gold Standard 0% Interest Checking', 'subtype': 'checking', 'type': 'depository'}, {'account_id': 'nPw8Qa1zkjsbLMm635gDcQP64jRoomU6jpV7Q', 'balances': {'available': 200, 'current': 210, 'iso_currency_code': 'USD', 'limit': None, 'unofficial_currency_code': None}, 'mask': '1111', 'name': 'Plaid Saving', 'official_name': 'Plaid Silver Standard 0.1% Interest Saving', 'subtype': 'savings', 'type': 'depository'}, {'account_id': 'blgmzvQJAqs1dLv3x5neTMl5yZj44nfVXyK96', 'balances': {'available': None, 'current': 1000, 'iso_currency_code': 'USD', 'limit': None, 'unofficial_currency_code': None}, 'mask': '2222', 'name': 'Plaid CD', 'official_name': 'Plaid Bronze Standard 0.2% Interest CD', 'subtype': 'cd', 'type': 'depository'}, {'accou
# ...

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())
# Retrieve the transactions for the last 90 days
transactions_response = client.Transactions.get(access_token,start_date,end_date)
# Print the transactions
print(json.dumps(transactions_response['transactions'][:2],indent=4, sort_keys=True))
# Out:
# [
#     {
#         "account_id": "mNb8XdZkzPsb1e9DQrdMcJGo4DA119CLDwpKe",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-07-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "merchant_name": "United Airlines",
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
# ...

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
for transactions in transactions_response['transactions']:
    print(transactions['category'][0])
# Out:
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %% [markdown]
# # Define an empty DataFrame and set the columns as date, name, amount, and category

# %%
df = pd.DataFrame(columns=["date", "name","amount", "category"])
transactions = transactions_response["transactions"]

# %%
for transactions in transactions_response["transactions"]:
    print(transactions["category"][0])
# Out:
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer

# %%
budget_df=pd.DataFrame()
date=[]
name=[]
amount=[]
category=[] 
# Retrieve all the transactions
for transactions in transactions_response["transactions"]:
    date.append(transactions["date"])
    name.append(transactions["name"])
    amount.append(transactions["amount"])
    category.append(transactions["category"][0])
# Populate the transactions DataFrame with the transactions data
budget_df["date"]=date
budget_df["name"]=name
budget_df["amount"]=amount
budget_df["category"]=category
# Display sample data from the DataFrame 
budget_df.head()
# Out:
#          date                       name   amount        category
# 0  2020-07-29            United Airlines   500.00          Travel
# 1  2020-07-27     Uber 072515 SF**POOL**     6.33          Travel
# 2  2020-07-24                 Tectra Inc   500.00  Food and Drink
# 3  2020-07-23  AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 4  2020-07-23                        KFC   500.00  Food and Drink

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
budget_df.dtypes
# Out:
# date         object
# name         object
# amount      float64
# category     object
# dtype: object

# %%
# Make any required data type transformation
budget_df = budget_df.set_index(pd.to_datetime(budget_df["date"], infer_datetime_format=True)).copy()
budget_df = budget_df.sort_index()
budget_df
# Out:
#                   date                                   name   amount  \
# date
# 2020-07-09  2020-07-09                           INTRST PYMNT    -4.22
# 2020-07-10  2020-07-10                               SparkFun    89.40
# 2020-07-11  2020-07-11                             McDonald's    12.00
# 2020-07-11  2020-07-11                              Starbucks     4.33
# 2020-07-12  2020-07-12                    Touchstone Climbing    78.50
# 2020-07-12  2020-07-12                        United Airlines  -500.00
# 2020-07-13  2020-07-13  ACH Electronic CreditGUSTO PAY 123456  5850.00
# 2020-07-13  2020-07-13                   CD DEPOSIT .INITIAL.  1000.00
# 2020-07-14  2020-07-14           CREDIT CARD 3333 PAYMENT *//    25.00
# 2020-07-14  2020-07-14                 Uber 063015 SF**POOL**     5.40
# 2020-07-23  2020-07-23              AUTOMATIC PAYMENT - THANK  2078.50
# 2020-07-23  2020-07-23                                    KFC   500.00
# ...

# %%
# Set the date column as index
budget_df= budget_df.drop(columns=["date"])
budget_df
# Out:
#                                              name   amount        category
# date
# 2020-07-09                           INTRST PYMNT    -4.22        Transfer
# 2020-07-10                               SparkFun    89.40  Food and Drink
# 2020-07-11                             McDonald's    12.00  Food and Drink
# 2020-07-11                              Starbucks     4.33  Food and Drink
# 2020-07-12                    Touchstone Climbing    78.50      Recreation
# 2020-07-12                        United Airlines  -500.00          Travel
# 2020-07-13  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-07-13                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-07-14           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-07-14                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-07-23              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# ...

# %%
# Display sample data
budget_df.dtypes
# Out:
# name         object
# amount      float64
# category     object
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch de income data
start_date_365 = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-365))
end_date_365 = '{:%Y-%m-%d}'.format(datetime.datetime.now())
transactions_response_365 = client.Transactions.get(access_token,start_date_365,end_date_365)
# Print the income data
print(json.dumps(transactions_response_365['transactions'][-1],indent=4, sort_keys=True))
# Out:
# {
#     "account_id": "nPw8Qa1zkjsbLMm635gDcQP64jRoomU6jpV7Q",
#     "account_owner": null,
#     "amount": -4.22,
#     "authorized_date": null,
#     "category": [
#         "Transfer",
#         "Credit"
#     ],
#     "category_id": "21005000",
#     "date": "2020-07-09",
#     "iso_currency_code": "USD",
#     "location": {
#         "address": null,
#         "city": null,
#         "country": null,
#         "lat": null,
#         "lon": null,
#         "postal_code": null,
#         "region": null,
#         "store_number": null
#     },
#     "merchant_name": null,
#     "name": "INTRST PYMNT",
#     "payment_channel": "other",
#     "payment_meta": {
#         "by_order_of": null,
#         "payee": null,
#         "payer": null,
#         "payment_method": null,
#         "payment_processor": null,
#         "ppd_id": null,
#         "reason": null,
#         "reference_number": null
#     },
#     "pending": false,
#     "pending_transaction_id": null,
# ...

# %%
# Determine the previous year's gross income and print the results
previous_year=transactions_response_365 ['transactions']

# %%
previous_year
# Out:
# [{'account_id': 'mNb8XdZkzPsb1e9DQrdMcJGo4DA119CLDwpKe',
#   'account_owner': None,
#   'amount': 500,
#   'authorized_date': None,
#   'category': ['Travel', 'Airlines and Aviation Services'],
#   'category_id': '22001000',
#   'date': '2020-07-29',
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#    'city': None,
#    'country': None,
#    'lat': None,
#    'lon': None,
#    'postal_code': None,
#    'region': None,
#    'store_number': None},
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#    'payee': None,
#    'payer': None,
#    'payment_method': None,
#    'payment_processor': None,
#    'ppd_id': None,
#    'reason': None,
#    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'transaction_code': None,
#   'transaction_id': 'qe981PpxdQcNglR4Q9KaT7E9LN6jgzhdkxkL4',
#   'transaction_type': 'special',
# ...

# %%
# Determine the current monthly income and print the results
current_monthly=transactions_response_365 ['transactions']

# %%
current_monthly
# Out:
# [{'account_id': 'mNb8XdZkzPsb1e9DQrdMcJGo4DA119CLDwpKe',
#   'account_owner': None,
#   'amount': 500,
#   'authorized_date': None,
#   'category': ['Travel', 'Airlines and Aviation Services'],
#   'category_id': '22001000',
#   'date': '2020-07-29',
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#    'city': None,
#    'country': None,
#    'lat': None,
#    'lon': None,
#    'postal_code': None,
#    'region': None,
#    'store_number': None},
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#    'payee': None,
#    'payer': None,
#    'payment_method': None,
#    'payment_processor': None,
#    'ppd_id': None,
#    'reason': None,
#    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'transaction_code': None,
#   'transaction_id': 'qe981PpxdQcNglR4Q9KaT7E9LN6jgzhdkxkL4',
#   'transaction_type': 'special',
# ...

# %%
# Determine the projected yearly income and print the results
projected_yearly_income=transactions_response_365 ['transactions']

# %%
projected_yearly_income
# Out:
# [{'account_id': 'mNb8XdZkzPsb1e9DQrdMcJGo4DA119CLDwpKe',
#   'account_owner': None,
#   'amount': 500,
#   'authorized_date': None,
#   'category': ['Travel', 'Airlines and Aviation Services'],
#   'category_id': '22001000',
#   'date': '2020-07-29',
#   'iso_currency_code': 'USD',
#   'location': {'address': None,
#    'city': None,
#    'country': None,
#    'lat': None,
#    'lon': None,
#    'postal_code': None,
#    'region': None,
#    'store_number': None},
#   'merchant_name': 'United Airlines',
#   'name': 'United Airlines',
#   'payment_channel': 'in store',
#   'payment_meta': {'by_order_of': None,
#    'payee': None,
#    'payer': None,
#    'payment_method': None,
#    'payment_processor': None,
#    'ppd_id': None,
#    'reason': None,
#    'reference_number': None},
#   'pending': False,
#   'pending_transaction_id': None,
#   'transaction_code': None,
#   'transaction_id': 'qe981PpxdQcNglR4Q9KaT7E9LN6jgzhdkxkL4',
#   'transaction_type': 'special',
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# Compute the total expenses per category
category_group = budget_df ['category'].value_counts()
# Display the expenses per catefory
category_group
# Out:
# Food and Drink    5
# Travel            4
# Transfer          3
# Payment           2
# Recreation        1
# Shops             1
# Name: category, dtype: int64

# %%
# Create a spending categories pie chart.
category_group.plot(kind='pie')

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
total_expense = budget_df
# Display sample data
total_expense
# Out:
#                                              name   amount        category
# date
# 2020-07-09                           INTRST PYMNT    -4.22        Transfer
# 2020-07-10                               SparkFun    89.40  Food and Drink
# 2020-07-11                             McDonald's    12.00  Food and Drink
# 2020-07-11                              Starbucks     4.33  Food and Drink
# 2020-07-12                    Touchstone Climbing    78.50      Recreation
# 2020-07-12                        United Airlines  -500.00          Travel
# 2020-07-13  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 2020-07-13                   CD DEPOSIT .INITIAL.  1000.00        Transfer
# 2020-07-14           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 2020-07-14                 Uber 063015 SF**POOL**     5.40          Travel
# 2020-07-23              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# ...

# %%
# Create a spending per month bar chart
total_expense.plot.bar(legend=None, title="A Categorical Breakdown of Spending Habits Based off Number of Transactions")
